# %% [markdown]
# # Извлечение данных из коллекции новостных текстов
#
# Данные расположены  [в файле data/news.tar.gz](data/news.tar.gz). С некоторых новостных сайтов был загружен архив новостей а  несколько лет, причем каждая новость принаделжит к какой-то рубрике: `science`, `style`, `culture`, `life`, `economics`, `business`, `travel`, `forces`, `media`, `sport`
#
#
# В каждой строке файла содержится метка рубрики, заголовок новостной статьи и сам текст статьи, например:
#
#         sport <tab> Сборная Канады по хоккею разгромила чехов <tab> Сборная Канады по хоккею крупно об...
#
# С помощью [Yargy](https://github.com/natasha/yargy) или [Томита-парсера](https://github.com/yandex/tomita-parser) извлеките данные, которые можно описать структурой вида:
#
#
# ```python
# @dataclass
# class Entry:
#     name: str
#     birth_date: Optional[str]
#     birth_place: Optional[str]
# ```

# %%
import gzip

from dataclasses import dataclass
from typing import Iterator

@dataclass
class Text:
    label: str
    title: str
    text: str
    
file_path = "D://Nlp'23//nlp-2023//data//news.txt.gz"

def read_texts(fn: str) -> Iterator[Text]:
    with gzip.open(fn, "rt", encoding="utf-8") as f:
        for line in f:
            yield Text(*line.strip().split("\t"))

texts = list(read_texts(file_path))

# %%
from yargy import Parser, rule, and_, not_, or_
from yargy.predicates import dictionary,  gte, lte, is_capitalized
from yargy.pipelines import  morph_pipeline, pipeline
from yargy.interpretation import fact
from yargy.predicates import gram
from yargy.relations import gnc_relation

Name = fact(
    'Name',
    ['first', 'last'],
)

Date = fact(
    'Date',
    ['year', 'month', 'day']
)

Birth_place = fact(
    'Birth_place',
    ['name']
)

Entry = fact(
    'Entry',
    ['full_name', 'birth_date', 'birth_place']
)

# %%
LAST = and_(
    gram('Surn'),
    not_(gram('Abbr')),
)

FIRST = and_(
    gram('Name'),
    not_(gram('Abbr')),
)

gnc = gnc_relation()

NAME = rule( 
    or_(
    
    rule(
        FIRST.interpretation(Name.first).match(gnc),
        LAST.interpretation(Name.last).match(gnc)
        ),
    rule(
        LAST.interpretation(Name.last).match(gnc),
        FIRST.interpretation(Name.first).match(gnc)
        )
       )
    ).interpretation(
    Name
    )

# %%
BORN_VERB = morph_pipeline([                            
                             'появился в',                              
                             'появился на свет в',     
                             'родился в',                            
                             'появился',                              
                             'появился на свет',     
                             'родился',
                             'был рожден'      
                            ])

BIRTH_PlACE_CITY = rule(
    gram("NOUN").optional().repeatable(),
    and_(
        is_capitalized(),
        gram("NOUN")
    )
).interpretation(Birth_place.name) 

BIRTH_PLACE = rule(
    BIRTH_PlACE_CITY.interpretation(Birth_place.name)
    ).interpretation(Birth_place)

# %%
BIRTH_TAG = morph_pipeline([                            
                             'в'     
                            ])

MONTHS = {
    'январь': 1,
    'февраль': 2,
    'март': 3,
    'апрель': 4,
    'май': 5,
    'июнь': 6,
    'июль': 7,
    'август': 8,
    'сентябрь': 9,
    'октябрь': 10,
    'ноябрь': 11,
    'декабрь': 12
}

DATE_SEP = pipeline(['.', ':', '/'])

MONTH_NAME = dictionary(
    MONTHS
).interpretation(
    Date.month.normalized().custom(MONTHS.get)
)

DAY = and_(
    gte(1),
    lte(31)
).interpretation(
    Date.day.custom(int)
)

YEAR = and_(
    gte(1900),
    lte(2100)
).interpretation(
    Date.year.custom(int)
)

DATE_WITH_MONTH_IN_NUM = rule(
    DAY,
    DATE_SEP.optional (),

    and_( gte(1),
          lte(12)
        ).interpretation(
     Date.month.custom(int)
    ), 

    DATE_SEP.optional(),
    YEAR.optional()
)

DATE_WITH_MONTH_IN_WORD = rule(
    DAY,
    DATE_SEP.optional(),
    MONTH_NAME.optional(), 
    DATE_SEP.optional(),
    YEAR.optional()
)

# разные версии представления даты: месяц словом и через раздилитель (., / или :)

DATE = rule(
    or_(
        DATE_WITH_MONTH_IN_WORD, 
        DATE_WITH_MONTH_IN_NUM
       )
).interpretation(Date)

# %%
from tqdm import tqdm 

#разные комбинации информации о человеке

RULE = or_ (

    rule(    
        NAME.interpretation(Entry.full_name),
        BORN_VERB,
        BIRTH_TAG.optional(),
        BIRTH_PLACE.interpretation(Entry.birth_place).optional(),
        BIRTH_TAG.optional(),
        DATE.interpretation(Entry.birth_date).optional()
    ),


    rule(
        NAME.interpretation(Entry.full_name),
        BORN_VERB,
        BIRTH_TAG.optional(),
        DATE.interpretation(Entry.birth_date).optional(),
        BIRTH_TAG.optional(),
        BIRTH_PLACE.interpretation(Entry.birth_place).optional()
    ),

    rule(
        NAME.interpretation(Entry.full_name),
        BIRTH_TAG.optional(),
        DATE.interpretation(Entry.birth_date).optional(),
        BORN_VERB,
        BIRTH_TAG.optional(),
        BIRTH_PLACE.interpretation(Entry.birth_place).optional()
    ),

        rule(
        NAME.interpretation(Entry.full_name),
        BIRTH_TAG.optional(),
        BIRTH_PLACE.interpretation(Entry.birth_place).optional(),
        BORN_VERB,
        BIRTH_TAG.optional(),
        DATE.interpretation(Entry.birth_date).optional()
    ),

    rule( 
        NAME.interpretation(Entry.full_name)
        )
    
    ).interpretation(
    Entry
)

# %%
parser = Parser(RULE)

for text in tqdm(texts, disable=True):
    try:
        for match in parser.findall(text.text):
         print(match.fact)
    except:
       pass
# Out:
# Entry(full_name=Name(first='Матс', last='Сундин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимир', last='Филиппов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Ильгизу', last='Фахриеву'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Михаилом', last='Прохоровым'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Бена', last='Николсона'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Анри', last='Матисса'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Пабло', last='Пикассо'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Жоржа', last='Брака'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимиром', last='Путиным'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Леонида', last='Брежнева'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Юрий', last='Андропов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Игорь', last='Денисов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Ларри', last='Гагосян'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Виктор', last='Пинчук'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Марину', last='Абрамович'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Энди', last='Коулсон'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Руперта', last='Мердока'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Энди', last='Коулсона'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Леонида', last='Слуцкого'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Юлия', last='Александрова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Елена', last='Валюшкина'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Валентина', last='Мазулина'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Андрея', last='Першина'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Игорь', last='Артемьев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Эльвира', last='Набиуллина'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Михаил', last='Сухов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимиром', last='Путиным'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимир', last='Долинский'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Марина', last='Могилевская'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Анна', last='Терехова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Юрий', last='Чайка'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Александру', last='Бастрыкину'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дениса', last='Вороненкова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Отари', last='Кобахидзе'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Майкла', last='Джексона'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Майкл', last='Джексон'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Хайо', last='Зеппельт'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Ольга', last='Скабеева'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='матчМария', last='Шарапова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Григорий', last='Родченков'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Наталью', last='Желанову'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Вера', last='Брежнева'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Сергей', last='Косырев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дмитрия', last='Циликина'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дмитрий', last='Циликин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Вагит', last='Алекперов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Вагит', last='Алекперов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Джастин', last='Грэй'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Сида', last='Вишеса'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Сидом', last='Вишесом'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Алана', last='Паркера'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Сида', last='Вишеса'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Сид', last='Вишес'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Александр', last='Шпрыгин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Марку', last='Цукербергу'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Борис', last='Гребенщиков'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Джеки', last='Смит'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Джеки', last='Смит'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Джеки', last='Смит'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Галину', last='Немову'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Алексея', last='Немова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Галина', last='Немова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дмитрий', last='Чугунов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дмитрий', last='Песков'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Виктора', last='Кирьянова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дмитрий', last='Комбаровы'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Денис', last='Глушаков'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Евгений', last='Макеев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Сергей', last='Паршивлюк'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Юра', last='Мовсисян'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Романом', last='Широковым'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дмитрия', last='Аленичева'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Кирилла', last='Комбарова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Андрей', last='Голубков'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Джозефа', last='Киттингера'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Поля', last='Сезанна'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Поля', last='Сезанна'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Огюста', last='Ренуара'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Анри', last='Матисса'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Пабло', last='Пикассо'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Эдгара', last='Дега'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Клода', last='Моне'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Джанет', last='Джексон'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Джанет', last='Джексон'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Джанет', last='Джексон'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Джанет', last='Джексон'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Майкл', last='Джексон'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Джанет', last='Джексон'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Сара', last='Полсон'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимир', last='Путин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дмитрий', last='Песков'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дмитрий', last='Рогозин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Сергей', last='Шойгу'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Валерий', last='Герасимов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Юрий', last='Борисов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Игорь', last='Комаров'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Андрея', last='Мельниченко'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Филипп', last='Старк'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимир', last='Путин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Теунис', last='Тенбрук'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Теунис', last='Тенбрук'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Теуниса', last='Тенбрука'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Алексей', last='Кудрин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Алексей', last='Кудрин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Льва', last='Яшина'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Карен', last='Оганесян'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Максим', last='Матвеев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Валерии', last='Харламове'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Льву', last='Яшину'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимир', last='Путин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дени', last='Мирзоева'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Авдотьи', last='Смирновой'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Алексея', last='Сидорова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Олега', last='Погодина'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Карена', last='Оганесяна'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Алены', last='Званцовой'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Кевин', last='Бейтс'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Кевина', last='Бейтса'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Алексей', last='Пажитнов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Кэннинг', last='Эрин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дункана', last='Брауна'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Брюс', last='Робертсон'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Лидию', last='Рыхлову'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дмитрию', last='Рогозину'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимира', last='Липунова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Сергей', last='Дарькин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Роджер', last='Уотерс'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дэвид', last='Гилмор'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Ник', last='Мейсон'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Мария', last='Захарова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Сергей', last='Стрельбицкий'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Расселу', last='Кроу'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Василий', last='Быков'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Василий', last='Быков'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Василий', last='Быков'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Леонарда', last='Эйлера'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Пафнутием', last='Чебышевым'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Георгом', last='Риманом'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Григорием', last='Перельманом'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Джеймса', last='Кэмерона'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Марк', last='Цукерберг'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Авдотья', last='Смирнова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Гарри', last='Поттер'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Билл', last='Мюррей'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Джон', last='Гудман'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Джош', last='Холлоуэй'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Никиты', last='Хрущева'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Сергея', last='Королева'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Джон', last='Ангер'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Джон', last='Ангер'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Джон', last='Ангер'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дмитрий', last='Муратов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Мэтт', last='Смит'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Брент', last='Сибрук'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Джеффа', last='Картера'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Вячеслав', last='Войнов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Лиам', last='Галлахер'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Руперта', last='Мердока'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Василий', last='Баранов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимира', last='Путина'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Ивана', last='Таврина'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Алишера', last='Усманова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Александр', last='Невзоров'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Валентины', last='Матвиенко'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Александра', last='Невзорова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Александра', last='Невзорова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Александр', last='Невзоров'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Оливер', last='Экман'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Антон', last='Худобин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Сергей', last='Плотников'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Сергей', last='Мозякин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Александр', last='Попов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимир', last='Путин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Игорь', last='Шувалов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Андрей', last='Белоусов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Джульетта', last='Старлинг'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Кристиан', last='Шмидт'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Николаем', last='Федоровым'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дмитрий', last='Медведев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Джонс', last='Джермейн'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимир', last='Путин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимира', last='Хруничева'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дмитрий', last='Медведев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимира', last='Поповкина'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимиром', last='Путиным'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дмитрием', last='Медведевым'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Яков', last='Силин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дмитрий', last='Медведев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Арсений', last='Яценюк'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дмитрий', last='Песков'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Наталья', last='Яресько'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Николая', last='Жердева'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Томми', last='Ли'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Крис', last='Купер'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимир', last='Путин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Кристин', last='Райт'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Муаммаром', last='Каддафи'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Муаммара', last='Каддафи'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Александр', last='Грушко'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Федор', last='Лукьянов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимир', last='Путин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Анджея', last='Сапковского'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Романа', last='Терюшкова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Стивен', last='Уилсон'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Аркадий', last='Ткачук'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Георгий', last='Перский'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Аркадий', last='Ткачук'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Ксенией', last='Собчак'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Борис', last='Немцов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Алексей', last='Навальный'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Ксения', last='Собчак'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Ксения', last='Собчак'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Ксения', last='Собчак'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Барак', last='Обама'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Мишель', last='Обама'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Барак', last='Обама'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Джош', last='Сингер'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Адольфа', last='Гитлера'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Нил', last='Мориц'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Валерий', last='Ничушкин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Александр', last='Хохлачев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Кирилл', last='Дьяков'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Михаил', last='Григоренко'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Олега', last='Пешкова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Виктор', last='Бондарев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Олег', last='Королев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Олег', last='Пешков'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Константин', last='Мурахтин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Вагит', last='Алекперов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Арнольдом', last='Шварценеггером'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Валон', last='Бериша'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Сергей', last='Ковалев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Петр', last='Лукьянов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Юрием', last='Добровольским'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Сергеем', last='Нефедкиным'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Данилой', last='Шапошниковым'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Петром', last='Лукьяновым'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Ольгой', last='Маслиховой'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Алексея', last='Навального'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Никиты', last='Белых'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='якобы', last='Белых'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дмитрий', last='Медведев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Альбрехта', last='Дюрера'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Виктории', last='королевы'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Даниэль', last='Баренбойм'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Анна', last='Нетребко'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Амадеем', last='Моцартом'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Луиджи', last='Манцотти'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Майкла', last='Джексона'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Майкл', last='Джексон'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Марка', last='Цукерберга'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Николя', last='Саркози'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Руперта', last='Мердока'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Руперт', last='Мердок'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Тхай', last='Ли'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Джеймса', last='Бонда'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Джеймсе', last='Бонде'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Олег', last='Груненков'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Наполеоном', last='Бонапартом'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Николая', last='Азарова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Элвиса', last='Пресли'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Ричардом', last='Никсоном'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Вячеслав', last='Першуков'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Андрей', last='Говердовский'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='из', last='городов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Михаила', last='Глущенко'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Галины', last='Старовойтовой'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимира', last='Барсукова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Галина', last='Старовойтова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Андрей', last='Белоусов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Михаила', last='Ходорковского'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Юрий', last='Бойко'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Илью', last='Ковальчука'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Станислав', last='Галимов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Эмиль', last='Гарипов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Александр', last='Еременко'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Михаил', last='Григорьев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Денис', last='Денисов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Никита', last='Зайцев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дмитрий', last='Калинин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Евгений', last='Рясенский'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Глеб', last='Корягин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Андрей', last='Миронов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Александр', last='Кутузов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Евгений', last='Медведев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Илья', last='Никулин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Александр', last='Бурмистров'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Михаил', last='Варнаков'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Кирилл', last='Петров'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимир', last='Глазулин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Антон', last='Глинкин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Евгений', last='Дадонов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Илья', last='Зубов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Сергей', last='Калинин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Сергей', last='Широков'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Максим', last='Карпов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Максим', last='Пестушко'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Илья', last='Ковальчук'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Артемий', last='Панарин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Виктор', last='Тихонов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Евгений', last='Шипачев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дмитрий', last='Кугрышев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Николай', last='Прохоркин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Федор', last='Малыхин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Виктора', last='Януковича'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Юрий', last='Чайка'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Алексей', last='Ведев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Константином', last='Мурахтиным'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Игорь', last='Конашенков'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Олег', last='Пешков'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дмитрий', last='Медведев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Алексея', last='Улюкаева'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Алексей', last='Улюкаев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимиру', last='Путину'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Джона', last='Леннона'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Виктор', last='Лысенко'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дмитрий', last='Панкин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Сергей', last='Лазарев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Филипп', last='Киркоров'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Ольгу', last='Гореловскую'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Баннинга', last='Кока'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Джанни', last='Инфантино'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владислав', last='Масалов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владислав', last='Масалов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Ильхам', last='Алиев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Айдан', last='Салаховой'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Юрий', last='Аввакумов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Айдан', last='Салаховой'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Айдан', last='Салахова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Елена', last='Исинбаева'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Анна', last='Чичерова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Елена', last='Слесаренко'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Татьяна', last='Лысенко'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Юлия', last='Зарипова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Мария', last='Савинова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Юлия', last='Гущина'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Елена', last='Лашманова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Ольга', last='Каниськина'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Иван', last='Ухов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Юрий', last='Борзаковский'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Сергей', last='Кирдяпкин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Татьяна', last='Лебедева'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Максима', last='Кашулинского'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Александр', last='Винокуров'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Николя', last='Саркози'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимир', last='Якунин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Максим', last='Соколов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимир', last='Якунин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Сильвио', last='Берлускони'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Сильвио', last='Берлускони'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дженна', last='Джеймсон'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Саша', last='Грей'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Евгений', last='Савченко'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимир', last='Путин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дмитрий', last='Медведев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимир', last='Жириновский'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Александра', last='Зубкова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дмитрий', last='Труненков'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дмитрий', last='Гуджоян'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Олег', last='Бударгин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимир', last='Путин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимир', last='Путин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Джессика', last='Симпсон'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Лорен', last='Симпсон'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Фьюри', last='Тайсон'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимира', last='Кличко'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Фьюри', last='Тайсон'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимира', last='КличкоФьюри'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимир', last='Кличко'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Юэль', last='Киннаман'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Гэри', last='Олдман'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Хью', last='Лори'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Фредди', last='Крюгера'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Алихан', last='Гуцериев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Алихан', last='Гуцериев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Михаила', last='Гуцериева'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Алихан', last='Гуцериев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Михаил', last='Гуцериев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Бенедикт', last='Хэнкок'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='тем', last='Хэнкок'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Александр', last='Петров'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Евгением', last='Плющенко'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Уильямса', last='Дугласа'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='ли', last='Ромни'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Барак', last='Обама'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Брюс', last='Дикинсон'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Майкла', last='Дугласа'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Майкл', last='Дуглас'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Стив', last='Харрис'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Пола', last='Верховена'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Сергей', last='Шубенков'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дарья', last='Клишина'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Кубрат', last='Пулев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимиром', last='Кличко'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Андрея', last='Зализняка'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Рэнди', last='Гербера'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Александра', last='Овечкина'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Евгением', last='Малкиным'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Джейсон', last='Рубин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Джейсон', last='Рубин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Джанни', last='Инфантино'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Джанни', last='Инфантино'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Павел', last='Хамидулин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Илья', last='Ткаченко'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Екатериной', last='Рязановой'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Алексей', last='Горшков'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Мерил', last='Дэвис'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Чарли', last='Уайт'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Екатерина', last='Боброва'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дмитрий', last='Соловьев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Тони', last='Блэр'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Бориса', last='Грызлова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дмитрий', last='Грызлов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дмитрий', last='Грызлов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дмитрия', last='Грызлова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Джеймс', last='Уильямсон'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Ирина', last='Тюрина'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Сергея', last='Швецова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='ли', last='Каплан'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Ричарда', last='Макларена'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дмитрий', last='Козак'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Искандара', last='Махмудова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимира', last='Потанина'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимир', last='Поповкин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимир', last='Поповкин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Захар', last='Прилепин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Михаила', last='Тарковского'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Евгения', last='роман'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимира', last='Маяковского'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Лилии', last='Брик'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Алексея', last='Навального'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Константина', last='Янкаускаса'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Ольга', last='Горелик'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Константин', last='Янкаускас'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Алексея', last='Навального'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимир', last='Ашурков'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Николай', last='Ляскин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Константин', last='Янкаускас'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимир', last='Ашурков'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Николай', last='Ляскин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='амадин', last='гульдовых'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Юрия', last='Лужкова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимиру', last='Путину'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Леонида', last='Гозмана'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Бориса', last='Немцова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Сергея', last='Румянцева'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Артур', last='Анишин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Юрия', last='Валуева'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Капанен', last='Нико'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Ростада', last='Кнута'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Сергея', last='Полонского'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дмитрию', last='Луценко'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Тима', last='Бертона'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Джейсон', last='Шварцман'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Джона', last='романа'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Джин', last='Сперлинг'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Барака', last='Обамы'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Майка', last='Пондсмита'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Евгений', last='Гинер'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Александр', last='Маркин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Мария', last='Шарапова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Мария', last='Шарапова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Семен', last='Елистратов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Екатерина', last='Боброва'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Александр', last='Маркин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Юрий', last='Иванов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Юрий', last='Иванов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Юрий', last='Иванов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Александр', last='Зубков'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Никита', last='Крылов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Юрий', last='Бирюков'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Денис', last='Лебедев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимир', last='Лебедева'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Игорь', last='Бутман'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Юрий', last='Башмет'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Мария', last='Александрова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Юрий', last='Башмет'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Джон', last='Ранкин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Мария', last='Криттель'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Брайан', last='Уилсон'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Майк', last='Лав'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Алан', last='Джардин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дэвид', last='Маркс'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Крис', last='Браун'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Тони', last='Беннетт'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Майкл', last='Блумберг'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Эльвира', last='Набиуллина'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Ярослава', last='Кузьминова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Эльвира', last='Набиуллина'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Арама', last='Габрелянова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимира', last='Путина'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Михаила', last='Саакашвили'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Кирилла', last='Миронова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Вагит', last='Алекперов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Игорь', last='Шувалов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дмитрий', last='Медведев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Ларри', last='Клейман'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Марка', last='Цукерберга'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дмитрий', last='Медведев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Андрей', last='Рябинский'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Ричарда', last='Макларена'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Николай', last='Грачев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Вагит', last='Алекперов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дмитрию', last='Медведеву'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимиру', last='Путину'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Андрея', last='Костина'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Сергей', last='Прядкин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дмитрий', last='Медведев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Сандра', last='Буллок'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Олег', last='Жолобов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимир', last='Максимов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Андрея', last='Колесникова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Никита', last='Одинцов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Павла', last='Астахова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Антон', last='Астахов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Павла', last='Астахова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Анна', last='Левченко'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Николай', last='Никифоров'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Кирилла', last='Серебренникова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Александр', last='Круглов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='из', last='баров'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Стива', last='Джобса'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Станислав', last='Воскресенский'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Барак', last='Обама'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дэвид', last='Гибсон'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Джейк', last='Дэвис'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Екатерина', last='Михайлова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Константина', last='Коровина'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Петра', last='Кончаловского'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Александра', last='Яковлева'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Святослава', last='Рериха'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Ивана', last='Айвазовского'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Ильи', last='Репина'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Ивана', last='Шишкина'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимир', last='Путин'), birth_date=None, birth_place=None)
# ...
# Entry(full_name=Name(first='Бойз', last='Янг'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Василия', last='Березуцкого'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Эдуардом', last='Шеварнадзе'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Алексей', last='Венедиктов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимир', last='Варфоломеев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Алексей', last='Венедиктов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Юрия', last='Федутинова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Алексей', last='Венедиктов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Алексей', last='Венедиктов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимир', last='Путин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Франсуа', last='Олланд'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Француа', last='Олланд'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимир', last='Путин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Сергей', last='Горьков'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимира', last='Дмитриева'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Олега', last='Дормана'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Лилианне', last='Лунгиной'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Алексей', last='Пивоваров'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Георгия', last='Жукова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Леонида', last='Парфенова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Чарльз', last='Дарвин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Руслан', last='Бальбек'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Сергей', last='Карякин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Сергей', last='Карякин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Сергей', last='Карякин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимир', last='Путин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Алан', last='Джойс'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Алексей', last='Улюкаев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Гарегин', last='Тосунян'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Сергея', last='Давыдова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Курбан', last='Бердыев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Кима', last='Чельстрема'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Майклом', last='Амодтом'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Михаила', last='Фрадкова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Павла', last='Фрадкова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Михаила', last='Фрадкова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Павле', last='Фрадкове'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Николая', last='Патрушева'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Павел', last='Фрадков'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Юрий', last='Петров'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Мухарбек', last='Декажев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Михаил', last='Мишустин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дмитрию', last='Киселеву'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимира', last='Путина'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Светлана', last='Миронюк'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дмитрий', last='Киселев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимир', last='Путин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Михаилу', last='Мамиашвили'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дмитрий', last='Свищев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Алексей', last='Попов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимиром', last='Путиным'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Юрий', last='Белкин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Наталью', last='Кашкарову'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Денис', last='Евсюков'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='ли', last='возможноВ'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Виктором', last='Рагозиным'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дмитрием', last='Менделеевым'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Мария', last='Шарапова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Анатолий', last='Васильченко'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Юлия', last='Ефимова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Евгений', last='Рылов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Елена', last='Алексеева'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Александр', last='Бортников'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Александр', last='Медведев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Евгения', last='Малкина'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Ольга', last='Подчуфарова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Екатерине', last='Юрловой'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Александру', last='Валову'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Александр', last='Попков'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дмитрию', last='Салтыковскому'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Бернарда', last='Голдберга'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Максимом', last='Григорьевым'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Вячеслава', last='Жигалова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Петру', last='Порошенко'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Эриха', last='Ледерера'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Эриха', last='Ледерера'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Эриха', last='Ледерера'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Анзор', last='Музаев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимира', last='Путина'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимир', last='Путин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Биллом', last='Мюрреем'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Майклом', last='Джорданом'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Памелой', last='Андерсон'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Франсуа', last='Олланда'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Андрея', last='Костина'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимира', last='Путина'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Сергей', last='Глазьев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимир', last='Путин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Юрию', last='Осипову'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Сергей', last='Глазьев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Сергей', last='Глазьев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Александр', last='Покрышкин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Николай', last='Гулаев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Фрэнком', last='Баумом'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Фрэнка', last='Баума'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Джеймса', last='Франко'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Джон', last='Дуглас'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Алексей', last='Моисеев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дмитрий', last='Медведев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Гарри', last='Поттера'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Джинни', last='Поттер'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Алексей', last='Воробьев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Алексей', last='Воробьев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Демьяна', last='Кудрявцева'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Алексей', last='Воробьев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Алишером', last='Усмановым'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Екатерина', last='Краснова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Григория', last='Пирумова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Олег', last='Иванов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дмитрий', last='Сергеев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Александр', last='Коченов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Никита', last='Колесников'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Михаил', last='Дудко'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Всеволод', last='Чаплин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Йозефом', last='Блаттером'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Юрия', last='Шевчука'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимиром', last='Путиным'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Полины', last='Гагариной'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Юлия', last='Савичева'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Полина', last='Гагарина'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Борис', last='Гребенщиков'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Ежи', last='Энгель'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимир', last='Путин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимира', last='Путина'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Слай', last='Купер'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Натан', last='Дрейк'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Юрий', last='Зубарев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Алексей', last='Улюкаев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимира', last='Путина'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Игоря', last='Смольникова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Эмма', last='Уотсон'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Гарри', last='Поттер'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Эммы', last='Уотсон'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Майк', last='Ли'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дмитрий', last='Рогозин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Евгений', last='Кузнецов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Артемий', last='Панарин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Сергей', last='Шойгу'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Юлии', last='Ефимовой'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Артема', last='Пацева'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Алексея', last='Емелина'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Артуру', last='Джанибекяну'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Гарику', last='Мартиросяну'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Гамрлику', last='Роману'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Александр', last='Овечкин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Александр', last='Семин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дмитрий', last='Орлов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Альварес', last='Карлос'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Урсула', last='Грабовская'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Феликса', last='Фалька'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Пола', last='Бертона'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Барак', last='Обама'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Эльвира', last='Набиуллина'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Александр', last='Бастрыкин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Сержем', last='Саргсяном'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Валерий', last='Пермяков'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Сергей', last='Куприянов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Игорь', last='Сечин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Алексей', last='Миллер'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Гузель', last='Санжапова'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дин', last='Армстронг'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Сэм', last='Дэвидсон'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Фредди', last='Крюгер'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Александр', last='Старовойтов'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Владимир', last='Путин'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Евгений', last='Гонтмахер'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Дмитрий', last='Медведев'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Людмила', last='Вороненко'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Андреем', last='Виноградовым'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Людмила', last='Вороненко'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Леонид', last='Слуцкий'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Аркадия', last='Ротенберга'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Константина', last='Малофеева'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Константина', last='Малофеева'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Джорджа', last='Буша'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Билла', last='Клинтона'), birth_date=None, birth_place=None)
# Entry(full_name=Name(first='Сергея', last='Полонского'), birth_date=None, birth_place=None)
